# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Retreiving the dataframes

# %%
df1 = pd.read_csv('opel_corsa_01.csv', delimiter=';')
df2 = pd.read_csv('opel_corsa_02.csv', delimiter=';')
df3 = pd.read_csv('peugeot_207_01.csv', delimiter=';')
df4 = pd.read_csv('peugeot_207_02.csv', delimiter=';')

# %%
df1.head()
# Out:
#   AltitudeVariation VehicleSpeedInstantaneous VehicleSpeedAverage  \
# 0               NaN                         0                 NaN
# 1               NaN                         0                 NaN
# 2               NaN                       NaN                 NaN
# 3               NaN                       NaN                 NaN
# 4               NaN                         0                 NaN
#
#   VehicleSpeedVariance VehicleSpeedVariation LongitudinalAcceleration  \
# 0                  NaN                   NaN                   0,0156
# 1                  NaN                   NaN                   0,0156
# 2                  NaN                   NaN                   0,0273
# 3                  NaN                   NaN                   0,0391
# 4                  NaN                   NaN                   0,0469
#
#     EngineLoad  EngineCoolantTemperature  ManifoldAbsolutePressure  EngineRPM  \
# 0  25,49019623                        64                       100        801
# 1  25,49019623                        64                       100        803
# 2  25,88235283                        64                       100        800
# 3  25,88235283                        64                       100        798
# 4  25,88235283                        65                       100        798
#
#    MassAirFlow  IntakeAirTemperature VerticalAcceleration  \
# 0  7,849999905                    22              -0,0078
# 1  7,889999866                    22              -0,0156
# 2  7,769999981                    22              -0,0273
# 3  7,769999981                    22              -0,0273
# 4  7,940000057                    22              -0,0312
#
#   FuelConsumptionAverage      roadSurface                 traffic  \
# 0                    NaN  SmoothCondition  LowCongestionCondition
# 1                    NaN  SmoothCondition  LowCongestionCondition
# 2                    NaN  SmoothCondition  LowCongestionCondition
# 3                    NaN  SmoothCondition  LowCongestionCondition
# 4                    NaN  SmoothCondition  LowCongestionCondition
#
#     drivingStyle
# 0  EvenPaceStyle
# 1  EvenPaceStyle
# 2  EvenPaceStyle
# 3  EvenPaceStyle
# 4  EvenPaceStyle

# %%
df2.head()
# Out:
#   AltitudeVariation VehicleSpeedInstantaneous VehicleSpeedAverage  \
# 0               NaN                         0                 NaN
# 1               NaN                         0                 NaN
# 2               NaN                         0                 NaN
# 3               NaN                         0                 NaN
# 4               NaN                         0                 NaN
#
#   VehicleSpeedVariance VehicleSpeedVariation LongitudinalAcceleration  \
# 0                  NaN                   NaN                    0,263
# 1                  NaN                   NaN                   0,5886
# 2                  NaN                   NaN                   0,9271
# 3                  NaN                   NaN                   1,2814
# 4                  NaN                   NaN                   1,6305
#
#     EngineLoad  EngineCoolantTemperature  ManifoldAbsolutePressure  EngineRPM  \
# 0  34,50980377                        37                       100        857
# 1  34,50980377                        37                       100        857
# 2  34,50980377                        37                       100        855
# 3  34,11764908                        37                       100        858
# 4  34,50980377                        37                       100        858
#
#    MassAirFlow  IntakeAirTemperature VerticalAcceleration  \
# 0   8,31000042                    21               0,1051
# 1  8,949999809                    21                0,656
# 2  8,670000076                    21               1,3736
# 3  8,880000114                    20               2,1463
# 4  8,479999542                    21               2,9495
#
#   FuelConsumptionAverage      roadSurface                 traffic  \
# 0                    NaN  SmoothCondition  LowCongestionCondition
# 1                    NaN  SmoothCondition  LowCongestionCondition
# 2                    NaN  SmoothCondition  LowCongestionCondition
# 3                    NaN  SmoothCondition  LowCongestionCondition
# 4                    NaN  SmoothCondition  LowCongestionCondition
#
#     drivingStyle
# 0  EvenPaceStyle
# 1  EvenPaceStyle
# 2  EvenPaceStyle
# 3  EvenPaceStyle
# 4  EvenPaceStyle

# %%
df3.head()
# Out:
#   AltitudeVariation VehicleSpeedInstantaneous VehicleSpeedAverage  \
# 0               NaN                         0                 NaN
# 1               NaN                         0                 NaN
# 2               NaN                         0                 NaN
# 3               NaN                         0                 NaN
# 4               NaN                         0                 NaN
#
#   VehicleSpeedVariance VehicleSpeedVariation LongitudinalAcceleration  \
# 0                  NaN                   NaN                   0,0418
# 1                  NaN                   NaN                   0,0713
# 2                  NaN                   NaN                   0,0952
# 3                  NaN                   NaN                   0,1136
# 4                  NaN                   NaN                   0,1274
#
#     EngineLoad  EngineCoolantTemperature  ManifoldAbsolutePressure EngineRPM  \
# 0  36,47058868                      28.0                     100.0     802,5
# 1  36,47058868                      28.0                     100.0     802,5
# 2  36,47058868                      29.0                     100.0     798,5
# 3  36,47058868                      29.0                     100.0     798,5
# 4  36,47058868                      29.0                     100.0     804,5
#
#    MassAirFlow  IntakeAirTemperature VerticalAcceleration  \
# 0  10,30000019                  14.0               0,0118
# 1  10,30000019                  14.0              -0,0023
# 2  10,23999977                  14.0              -0,0135
# 3  10,23999977                  15.0              -0,0161
# 4  10,35999966                  15.0               -0,016
#
#   FuelConsumptionAverage      roadSurface                 traffic  \
# 0                    NaN  SmoothCondition  LowCongestionCondition
# 1                    NaN  SmoothCondition  LowCongestionCondition
# 2                    NaN  SmoothCondition  LowCongestionCondition
# 3                    NaN  SmoothCondition  LowCongestionCondition
# 4                    NaN  SmoothCondition  LowCongestionCondition
#
#     drivingStyle
# 0  EvenPaceStyle
# 1  EvenPaceStyle
# 2  EvenPaceStyle
# 3  EvenPaceStyle
# 4  EvenPaceStyle

# %%
df4.head()
# Out:
#   AltitudeVariation VehicleSpeedInstantaneous VehicleSpeedAverage  \
# 0               NaN                       NaN                 NaN
# 1               NaN                       NaN                 NaN
# 2               NaN                         0                 NaN
# 3               NaN                         0                 NaN
# 4               NaN                         0                 NaN
#
#   VehicleSpeedVariance VehicleSpeedVariation LongitudinalAcceleration  \
# 0                  NaN                   NaN                  -0,0477
# 1                  NaN                   NaN                  -0,0911
# 2                  NaN                   NaN                  -0,1335
# 3                  NaN                   NaN                  -0,1734
# 4                  NaN                   NaN                  -0,2131
#
#     EngineLoad  EngineCoolantTemperature  ManifoldAbsolutePressure EngineRPM  \
# 0  36,86274719                        22                       101       805
# 1  37,64706039                        22                       101       811
# 2  37,25490189                        22                       102       809
# 3  36,47058868                        22                       102       808
# 4  36,07843018                        22                       101     809,5
#
#    MassAirFlow  IntakeAirTemperature VerticalAcceleration  \
# 0  10,55000019                    13               0,0236
# 1  10,47000027                    13               0,0469
# 2  10,60999966                    13               0,0451
# 3  10,72000027                    13               0,0416
# 4  10,72000027                    13               0,0629
#
#   FuelConsumptionAverage      roadSurface                    traffic  \
# 0                    NaN  UnevenCondition  NormalCongestionCondition
# 1                    NaN  UnevenCondition  NormalCongestionCondition
# 2                    NaN  UnevenCondition  NormalCongestionCondition
# 3                    NaN  UnevenCondition  NormalCongestionCondition
# 4                    NaN  UnevenCondition  NormalCongestionCondition
#
#     drivingStyle
# 0  EvenPaceStyle
# 1  EvenPaceStyle
# 2  EvenPaceStyle
# 3  EvenPaceStyle
# 4  EvenPaceStyle

# %% [markdown]
# ## Combining the dataset

# %%
frames = [df1,df2,df3,df4]

df = pd.concat(frames)

# %%
df
# Out:
#      AltitudeVariation VehicleSpeedInstantaneous VehicleSpeedAverage  \
# 0                  NaN                         0                 NaN
# 1                  NaN                         0                 NaN
# 2                  NaN                       NaN                 NaN
# 3                  NaN                       NaN                 NaN
# 4                  NaN                         0                 NaN
# ...                ...                       ...                 ...
# 4618                 1               28,79999924         28,55999908
# 4619       1,699996948               30,59999847          28,5299991
# 4620       1,800003052               29,69999886         28,49999908
# 4621       2,100006104               29,69999886         28,40999908
# 4622               1,5               33,29999924         28,34999911
#
#      VehicleSpeedVariance VehicleSpeedVariation LongitudinalAcceleration  \
# 0                     NaN                   NaN                   0,0156
# 1                     NaN                   NaN                   0,0156
# 2                     NaN                   NaN                   0,0273
# 3                     NaN                   NaN                   0,0391
# 4                     NaN                   NaN                   0,0469
# ...                   ...                   ...                      ...
# 4618          57,19057079           3,600000381                  -0,0292
# 4619          57,01026584           1,799999237                  -0,0304
# 4620           56,8830454          -0,899999619                  -0,1684
# 4621          56,16090993                     0                  -0,0644
# 4622          55,34084256           3,600000381                  -0,1817
#
#        EngineLoad  EngineCoolantTemperature  ManifoldAbsolutePressure  \
# 0     25,49019623                      64.0                     100.0
# 1     25,49019623                      64.0                     100.0
# 2     25,88235283                      64.0                     100.0
# 3     25,88235283                      64.0                     100.0
# 4     25,88235283                      65.0                     100.0
# ...           ...                       ...                       ...
# 4618  25,88235283                      81.0                     115.0
# 4619  11,76470566                      81.0                     106.0
# 4620  98,03921509                      81.0                     106.0
# 4621  79,60784149                      80.0                     112.0
# 4622           80                      80.0                     113.0
#
#      EngineRPM  MassAirFlow  IntakeAirTemperature VerticalAcceleration  \
# 0          801  7,849999905                  22.0              -0,0078
# 1          803  7,889999866                  22.0              -0,0156
# 2          800  7,769999981                  22.0              -0,0273
# 3          798  7,769999981                  22.0              -0,0273
# 4          798  7,940000057                  22.0              -0,0312
# ...        ...          ...                   ...                  ...
# 4618    1755,5  20,46999931                  25.0              -0,1661
# 4619     736,5  17,73999977                  25.0              -0,1987
# 4620      1254  9,520000458                  24.0              -0,1156
# 4621      1254  14,90999985                  23.0               -0,076
# 4622    1363,5  15,32999992                  23.0              -0,0605
#
#      FuelConsumptionAverage      roadSurface                 traffic  \
# 0                       NaN  SmoothCondition  LowCongestionCondition
# 1                       NaN  SmoothCondition  LowCongestionCondition
# 2                       NaN  SmoothCondition  LowCongestionCondition
# 3                       NaN  SmoothCondition  LowCongestionCondition
# 4                       NaN  SmoothCondition  LowCongestionCondition
# ...                     ...              ...                     ...
# 4618            14,57800293  SmoothCondition  LowCongestionCondition
# 4619            14,58564186  SmoothCondition  LowCongestionCondition
# 4620            14,54729366  SmoothCondition  LowCongestionCondition
# 4621            14,54682827  SmoothCondition  LowCongestionCondition
# 4622            14,55406761  SmoothCondition  LowCongestionCondition
#
#        drivingStyle
# 0     EvenPaceStyle
# 1     EvenPaceStyle
# 2     EvenPaceStyle
# 3     EvenPaceStyle
# 4     EvenPaceStyle
# ...             ...
# 4618  EvenPaceStyle
# 4619  EvenPaceStyle
# 4620  EvenPaceStyle
# 4621  EvenPaceStyle
# 4622  EvenPaceStyle
#
# [24957 rows x 17 columns]

# %% [markdown]
# approximately 25000 rows obtained

# %% [markdown]
# # Data filtering

# %%
#dropping duplicates
df = df.drop_duplicates()

# %%
#dropping na values
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna()

# %%
df
# Out:
#      AltitudeVariation VehicleSpeedInstantaneous VehicleSpeedAverage  \
# 59          -2,2999878               25,67051888         13,22350089
# 60          -2,0999756               24,09425926         13,63891915
# 61                -1,5               22,74317932         14,03104293
# 62           0,1000366               22,29281998         14,17107305
# 63           0,0999756               23,64389992          14,3289535
# ...                ...                       ...                 ...
# 4618                 1               28,79999924         28,55999908
# 4619       1,699996948               30,59999847          28,5299991
# 4620       1,800003052               29,69999886         28,49999908
# 4621       2,100006104               29,69999886         28,40999908
# 4622               1,5               33,29999924         28,34999911
#
#      VehicleSpeedVariance VehicleSpeedVariation LongitudinalAcceleration  \
# 59            121,5926897            -2,4769802                   0,3555
# 60            120,4225707           -1,57625962                   0,4492
# 61            118,4567689           -1,35107994                   0,4258
# 62            117,5713084           -0,45035934                    0,414
# 63            117,0741485            1,35107994                   0,3945
# ...                   ...                   ...                      ...
# 4618          57,19057079           3,600000381                  -0,0292
# 4619          57,01026584           1,799999237                  -0,0304
# 4620           56,8830454          -0,899999619                  -0,1684
# 4621          56,16090993                     0                  -0,0644
# 4622          55,34084256           3,600000381                  -0,1817
#
#        EngineLoad  EngineCoolantTemperature  ManifoldAbsolutePressure  \
# 59    4,705882549                      68.0                     106.0
# 60    10,58823586                      68.0                     103.0
# 61    27,45098114                      68.0                     103.0
# 62    24,31372643                      69.0                     104.0
# 63             20                      69.0                     104.0
# ...           ...                       ...                       ...
# 4618  25,88235283                      81.0                     115.0
# 4619  11,76470566                      81.0                     106.0
# 4620  98,03921509                      81.0                     106.0
# 4621  79,60784149                      80.0                     112.0
# 4622           80                      80.0                     113.0
#
#      EngineRPM  MassAirFlow  IntakeAirTemperature VerticalAcceleration  \
# 59        1796  15,81000042                  24.0              -0,1133
# 60        1689  14,64999962                  22.0              -0,1289
# 61        1599  11,85000038                  21.0              -0,1328
# 62        1620  12,21000004                  20.0              -0,0859
# 63        1708  11,90999985                  21.0              -0,0664
# ...        ...          ...                   ...                  ...
# 4618    1755,5  20,46999931                  25.0              -0,1661
# 4619     736,5  17,73999977                  25.0              -0,1987
# 4620      1254  9,520000458                  24.0              -0,1156
# 4621      1254  14,90999985                  23.0               -0,076
# 4622    1363,5  15,32999992                  23.0              -0,0605
#
#      FuelConsumptionAverage      roadSurface                 traffic  \
# 59              19,49733543  SmoothCondition  LowCongestionCondition
# 60              19,51572227  SmoothCondition  LowCongestionCondition
# 61              19,44176483  SmoothCondition  LowCongestionCondition
# 62              19,38876915  SmoothCondition  LowCongestionCondition
# 63              19,30163765  SmoothCondition  LowCongestionCondition
# ...                     ...              ...                     ...
# 4618            14,57800293  SmoothCondition  LowCongestionCondition
# 4619            14,58564186  SmoothCondition  LowCongestionCondition
# 4620            14,54729366  SmoothCondition  LowCongestionCondition
# 4621            14,54682827  SmoothCondition  LowCongestionCondition
# 4622            14,55406761  SmoothCondition  LowCongestionCondition
#
#        drivingStyle
# 59    EvenPaceStyle
# 60    EvenPaceStyle
# 61    EvenPaceStyle
# 62    EvenPaceStyle
# 63    EvenPaceStyle
# ...             ...
# 4618  EvenPaceStyle
# 4619  EvenPaceStyle
# 4620  EvenPaceStyle
# 4621  EvenPaceStyle
# 4622  EvenPaceStyle
#
# [23762 rows x 17 columns]

# %% [markdown]
# rows reduced to 23.7 k

# %%
# resetting index
df = df.reset_index(drop=True)

# %%
print(df.dtypes)
# Out:
# AltitudeVariation             object
# VehicleSpeedInstantaneous     object
# VehicleSpeedAverage           object
# VehicleSpeedVariance          object
# VehicleSpeedVariation         object
# LongitudinalAcceleration      object
# EngineLoad                    object
# EngineCoolantTemperature     float64
# ManifoldAbsolutePressure     float64
# EngineRPM                     object
# MassAirFlow                   object
# IntakeAirTemperature         float64
# VerticalAcceleration          object
# FuelConsumptionAverage        object
# roadSurface                   object
# traffic                       object
# drivingStyle                  object
# dtype: object

# %% [markdown]
# ## Dropping irrelevant columns

# %%
# dropping target attributes other than traffic
df = df.drop(columns = ['drivingStyle','roadSurface','AltitudeVariation','VehicleSpeedVariation','VehicleSpeedInstantaneous','LongitudinalAcceleration','VerticalAcceleration'])

# %%
df
# Out:
#       VehicleSpeedAverage VehicleSpeedVariance   EngineLoad  \
# 0             13,22350089          121,5926897  4,705882549
# 1             13,63891915          120,4225707  10,58823586
# 2             14,03104293          118,4567689  27,45098114
# 3             14,17107305          117,5713084  24,31372643
# 4              14,3289535          117,0741485           20
# ...                   ...                  ...          ...
# 23757         28,55999908          57,19057079  25,88235283
# 23758          28,5299991          57,01026584  11,76470566
# 23759         28,49999908           56,8830454  98,03921509
# 23760         28,40999908          56,16090993  79,60784149
# 23761         28,34999911          55,34084256           80
#
#        EngineCoolantTemperature  ManifoldAbsolutePressure EngineRPM  \
# 0                          68.0                     106.0      1796
# 1                          68.0                     103.0      1689
# 2                          68.0                     103.0      1599
# 3                          69.0                     104.0      1620
# 4                          69.0                     104.0      1708
# ...                         ...                       ...       ...
# 23757                      81.0                     115.0    1755,5
# 23758                      81.0                     106.0     736,5
# 23759                      81.0                     106.0      1254
# 23760                      80.0                     112.0      1254
# 23761                      80.0                     113.0    1363,5
#
#        MassAirFlow  IntakeAirTemperature FuelConsumptionAverage  \
# 0      15,81000042                  24.0            19,49733543
# 1      14,64999962                  22.0            19,51572227
# 2      11,85000038                  21.0            19,44176483
# 3      12,21000004                  20.0            19,38876915
# 4      11,90999985                  21.0            19,30163765
# ...            ...                   ...                    ...
# 23757  20,46999931                  25.0            14,57800293
# 23758  17,73999977                  25.0            14,58564186
# 23759  9,520000458                  24.0            14,54729366
# 23760  14,90999985                  23.0            14,54682827
# 23761  15,32999992                  23.0            14,55406761
#
#                       traffic
# 0      LowCongestionCondition
# 1      LowCongestionCondition
# 2      LowCongestionCondition
# 3      LowCongestionCondition
# 4      LowCongestionCondition
# ...                       ...
# 23757  LowCongestionCondition
# 23758  LowCongestionCondition
# 23759  LowCongestionCondition
# 23760  LowCongestionCondition
# 23761  LowCongestionCondition
#
# [23762 rows x 10 columns]

# %% [markdown]
# we are left with 9 target columns

# %% [markdown]
# # Fixing the data type

# %%
df.dtypes
# Out:
# VehicleSpeedAverage          object
# VehicleSpeedVariance         object
# EngineLoad                   object
# EngineCoolantTemperature    float64
# ManifoldAbsolutePressure    float64
# EngineRPM                    object
# MassAirFlow                  object
# IntakeAirTemperature        float64
# FuelConsumptionAverage       object
# traffic                      object
# dtype: object

# %% [markdown]
# ### Categorical mapping of the feature

# %%
df['traffic'].value_counts()
# Out:
# traffic
# LowCongestionCondition       17757
# HighCongestionCondition       3015
# NormalCongestionCondition     2990
# Name: count, dtype: int64

# %%
# converting traffic data from string to int
category_mapping = {
    'LowCongestionCondition': 1,
    'NormalCongestionCondition': 2,
    'HighCongestionCondition': 3
}

df['traffic'] = df['traffic'].replace(category_mapping)
# Out:
# C:\Users\satvi\AppData\Local\Temp\ipykernel_3004\296678248.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['traffic'] = df['traffic'].replace(category_mapping)

# %%
df.dtypes
# Out:
# VehicleSpeedAverage         float64
# VehicleSpeedVariance        float64
# EngineLoad                  float64
# EngineCoolantTemperature    float64
# ManifoldAbsolutePressure    float64
# EngineRPM                   float64
# MassAirFlow                 float64
# IntakeAirTemperature        float64
# FuelConsumptionAverage      float64
# traffic                       int64
# dtype: object

# %%
# converting attributes from object to float datatype
for col in df.columns:
    if df[col].dtype == 'object' :  # Check if the column type is object (string)
        df[col] = df[col].str.replace(',', '.').astype(float)

# %%
df.dtypes
# Out:
# VehicleSpeedAverage         float64
# VehicleSpeedVariance        float64
# EngineLoad                  float64
# EngineCoolantTemperature    float64
# ManifoldAbsolutePressure    float64
# EngineRPM                   float64
# MassAirFlow                 float64
# IntakeAirTemperature        float64
# FuelConsumptionAverage      float64
# traffic                       int64
# dtype: object

# %% [markdown]
# ## Dataframe description

# %%
#dropping nan values
df = df.dropna()

# %%
df
# Out:
#        VehicleSpeedAverage  VehicleSpeedVariance  EngineLoad  \
# 11130             6.060000            115.840061   38.039215
# 11131             6.345000            117.200816   38.039215
# 11132             6.585000            117.559595   90.588234
# 11133             6.825000            117.801222   90.588234
# 11134             7.065000            117.925697   92.941177
# ...                    ...                   ...         ...
# 23757            28.559999             57.190571   25.882353
# 23758            28.529999             57.010266   11.764706
# 23759            28.499999             56.883045   98.039215
# 23760            28.409999             56.160910   79.607841
# 23761            28.349999             55.340843   80.000000
#
#        EngineCoolantTemperature  ManifoldAbsolutePressure  EngineRPM  \
# 11130                      31.0                     101.0      798.0
# 11131                      31.0                     101.0      797.5
# 11132                      32.0                     101.0      797.5
# 11133                      32.0                     101.0      726.0
# 11134                      32.0                     101.0      784.0
# ...                         ...                       ...        ...
# 23757                      81.0                     115.0     1755.5
# 23758                      81.0                     106.0      736.5
# 23759                      81.0                     106.0     1254.0
# 23760                      80.0                     112.0     1254.0
# 23761                      80.0                     113.0     1363.5
#
#        MassAirFlow  IntakeAirTemperature  FuelConsumptionAverage  traffic
# 11130     6.220000                  15.0               27.919697        1
# 11131     6.270000                  15.0               26.458355        1
# 11132     6.270000                  15.0               26.458355        1
# 11133     8.630000                  15.0               26.004126        1
# 11134     8.880000                  15.0               25.295498        1
# ...            ...                   ...                     ...      ...
# 23757    20.469999                  25.0               14.578003        1
# 23758    17.740000                  25.0               14.585642        1
# 23759     9.520000                  24.0               14.547294        1
# 23760    14.910000                  23.0               14.546828        1
# 23761    15.330000                  23.0               14.554068        1
#
# [12632 rows x 10 columns]

# %%
df.describe()
# Out:
#        VehicleSpeedAverage  VehicleSpeedVariance    EngineLoad  \
# count         12632.000000          12632.000000  12632.000000
# mean             38.486315            152.004142     43.223032
# std              30.514422            171.253388     29.022111
# min               0.000000              0.000000      0.000000
# 25%              16.152954             43.322241     25.098040
# 50%              30.389999            103.653911     38.039215
# 75%              46.638749            194.117638     72.549019
# max             114.884996           1418.370369    100.000000
#
#        EngineCoolantTemperature  ManifoldAbsolutePressure     EngineRPM  \
# count              12632.000000              12632.000000  12632.000000
# mean                  66.040769                111.844918   1386.259381
# std                   18.107771                 14.298477    573.308865
# min                   12.000000                 88.000000      0.000000
# 25%                   51.000000                103.000000    792.500000
# 50%                   78.000000                105.000000   1355.000000
# 75%                   79.000000                114.000000   1722.500000
# max                   86.000000                170.000000   2802.500000
#
#         MassAirFlow  IntakeAirTemperature  FuelConsumptionAverage  \
# count  12632.000000          12632.000000            12632.000000
# mean      15.042012             29.232980               14.294776
# std        8.606840             11.725428                3.943793
# min        0.880000              8.000000                7.847495
# 25%        6.130000             19.000000               11.412642
# 50%       15.270000             29.000000               13.757747
# 75%       20.940001             38.000000               16.511943
# max       38.549999             65.000000               30.672386
#
#             traffic
# count  12632.000000
# mean       1.585576
# std        0.796114
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        3.000000

# %% [markdown]
# # Visualising the feature-target correlation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# correlation matrix of only required attributes
correlation = df.corr()
plt.figure(figsize=(10, 8))
heatmap_df = sns.heatmap(
correlation,
vmin=-1, vmax=1, center=0,
cmap=sns.diverging_palette(250, 10, as_cmap=True),
square=True,annot=True,fmt=".2f"
)

# %% [markdown]
# # Removing outliers

# %%
df['traffic'].value_counts()
# Out:
# traffic
# 1    7705
# 3    2470
# 2    2457
# Name: count, dtype: int64

# %%
import openpyxl
from scipy import stats

# %%
df.reset_index(drop=True,inplace=True)

# %%
import scipy.optimize
def mahalanobis(x=None,data=None, cov=None):
    x_minus_mu=x-np.mean(data)
    if not cov:
        cov=np.cov(data.values.T)
    inv_covmat = scipy.linalg.inv(cov)
    left_term=np.dot(x_minus_mu, inv_covmat)
    mahal=np.dot(left_term, x_minus_mu.T)
    return mahal.diagonal()

cols=['VehicleSpeedAverage','VehicleSpeedVariance',	'EngineLoad',	'EngineCoolantTemperature',	'ManifoldAbsolutePressure',	'EngineRPM',	'MassAirFlow',	'IntakeAirTemperature', 'FuelConsumptionAverage']
final_df=df[cols]
final_df['mahala'] = mahalanobis(x=final_df,data=df[cols])
final_df.head()
# Out:
#    VehicleSpeedAverage  VehicleSpeedVariance  EngineLoad  \
# 0                6.060            115.840061   38.039215
# 1                6.345            117.200816   38.039215
# 2                6.585            117.559595   90.588234
# 3                6.825            117.801222   90.588234
# 4                7.065            117.925697   92.941177
#
#    EngineCoolantTemperature  ManifoldAbsolutePressure  EngineRPM  MassAirFlow  \
# 0                      31.0                     101.0      798.0         6.22
# 1                      31.0                     101.0      797.5         6.27
# 2                      32.0                     101.0      797.5         6.27
# 3                      32.0                     101.0      726.0         8.63
# 4                      32.0                     101.0      784.0         8.88
#
#    IntakeAirTemperature  FuelConsumptionAverage        mahala
# 0                  15.0               27.919697  18238.552051
# 1                  15.0               26.458355  18350.632719
# 2                  15.0               26.458355  18203.246212
# 3                  15.0               26.004126  17951.683422
# 4                  15.0               25.295498  18046.755732

# %%
final_df['mahala'].plot()
# Out:
# <Axes: >

# %%
# Filter for final_dataframe
filtered_final_df = final_df[(final_df['mahala'] > 18000) & (final_df['mahala'] < 19500)]

# Filter for outliers
outliers = final_df[(final_df['mahala'] < 18000) | (final_df['mahala'] > 19500)]

# %%
filtered_final_df = filtered_final_df.merge(df[['traffic']], left_index=True, right_index=True)

# %%
filtered_final_df['traffic'].value_counts()
# Out:
# traffic
# 1    7621
# 2    2437
# 3    2413
# Name: count, dtype: int64

# %%
filtered_final_df
# Out:
#        VehicleSpeedAverage  VehicleSpeedVariance  EngineLoad  \
# 0                 6.060000            115.840061   38.039215
# 1                 6.345000            117.200816   38.039215
# 2                 6.585000            117.559595   90.588234
# 4                 7.065000            117.925697   92.941177
# 5                 7.335000            118.419934   92.941177
# ...                    ...                   ...         ...
# 12626            28.619999             57.435859   69.803925
# 12627            28.559999             57.190571   25.882353
# 12629            28.499999             56.883045   98.039215
# 12630            28.409999             56.160910   79.607841
# 12631            28.349999             55.340843   80.000000
#
#        EngineCoolantTemperature  ManifoldAbsolutePressure  EngineRPM  \
# 0                          31.0                     101.0      798.0
# 1                          31.0                     101.0      797.5
# 2                          32.0                     101.0      797.5
# 4                          32.0                     101.0      784.0
# 5                          32.0                     101.0      784.0
# ...                         ...                       ...        ...
# 12626                      81.0                     119.0     1839.0
# 12627                      81.0                     115.0     1755.5
# 12629                      81.0                     106.0     1254.0
# 12630                      80.0                     112.0     1254.0
# 12631                      80.0                     113.0     1363.5
#
#        MassAirFlow  IntakeAirTemperature  FuelConsumptionAverage  \
# 0         6.220000                  15.0               27.919697
# 1         6.270000                  15.0               26.458355
# 2         6.270000                  15.0               26.458355
# 4         8.880000                  15.0               25.295498
# 5         8.880000                  15.0               25.295498
# ...            ...                   ...                     ...
# 12626    17.910000                  23.0               14.561829
# 12627    20.469999                  25.0               14.578003
# 12629     9.520000                  24.0               14.547294
# 12630    14.910000                  23.0               14.546828
# 12631    15.330000                  23.0               14.554068
#
#              mahala  traffic
# 0      18238.552051        1
# 1      18350.632719        1
# 2      18203.246212        1
# 4      18046.755732        1
# 5      18044.653598        1
# ...             ...      ...
# 12626  19010.660532        1
# 12627  18707.377488        1
# 12629  18747.761957        1
# 12630  18453.536243        1
# 12631  18559.838825        1
#
# [12471 rows x 11 columns]

# %%
outliers
# Out:
#        VehicleSpeedAverage  VehicleSpeedVariance  EngineLoad  \
# 3                 6.825000            117.801222   90.588234
# 181              39.059999             92.510229    0.000000
# 249              33.224999            186.170711   12.941176
# 710              15.914999             39.497565   23.921570
# 735              10.425000             83.506646   43.529411
# ...                    ...                   ...         ...
# 11849            11.125082             35.132579   87.058823
# 11850            11.381402             33.274751   74.901962
# 12304            29.873305            117.943430    1.568627
# 12335            32.909999            123.294808    0.000000
# 12628            28.529999             57.010266   11.764706
#
#        EngineCoolantTemperature  ManifoldAbsolutePressure  EngineRPM  \
# 3                          32.0                     101.0      726.0
# 181                        51.0                     111.0     1062.0
# 249                        59.0                     104.0      794.0
# 710                        79.0                     103.0      780.5
# 735                        80.0                     101.0      950.5
# ...                         ...                       ...        ...
# 11849                      16.0                     105.0     1397.5
# 11850                      16.0                     110.0     1637.5
# 12304                      62.0                     107.0      784.0
# 12335                      82.0                     110.0      887.0
# 12628                      81.0                     106.0      736.5
#
#        MassAirFlow  IntakeAirTemperature  FuelConsumptionAverage        mahala
# 3         8.630000                  15.0               26.004126  17951.683422
# 181      25.990000                  35.0               14.668366  17596.069178
# 249      18.160000                  22.0               13.471564  17946.160435
# 710      12.580000                  38.0               15.830131  17960.628925
# 735      13.380000                  39.0               17.607838  17863.256560
# ...            ...                   ...                     ...           ...
# 11849    19.110001                  11.0               28.396791  17890.494030
# 11850    23.469999                  13.0               28.426081  17886.923809
# 12304    22.520000                  21.0               16.893169  17386.063798
# 12335    21.660000                  24.0               11.260183  17838.760074
# 12628    17.740000                  25.0               14.585642  17665.248223
#
# [161 rows x 10 columns]

# %% [markdown]
# We obtained 161 outliers

# %%
df = filtered_final_df

# %%
df = df.drop(columns='mahala')

# %%
df
# Out:
#        VehicleSpeedAverage  VehicleSpeedVariance  EngineLoad  \
# 0                 6.060000            115.840061   38.039215
# 1                 6.345000            117.200816   38.039215
# 2                 6.585000            117.559595   90.588234
# 4                 7.065000            117.925697   92.941177
# 5                 7.335000            118.419934   92.941177
# ...                    ...                   ...         ...
# 12626            28.619999             57.435859   69.803925
# 12627            28.559999             57.190571   25.882353
# 12629            28.499999             56.883045   98.039215
# 12630            28.409999             56.160910   79.607841
# 12631            28.349999             55.340843   80.000000
#
#        EngineCoolantTemperature  ManifoldAbsolutePressure  EngineRPM  \
# 0                          31.0                     101.0      798.0
# 1                          31.0                     101.0      797.5
# 2                          32.0                     101.0      797.5
# 4                          32.0                     101.0      784.0
# 5                          32.0                     101.0      784.0
# ...                         ...                       ...        ...
# 12626                      81.0                     119.0     1839.0
# 12627                      81.0                     115.0     1755.5
# 12629                      81.0                     106.0     1254.0
# 12630                      80.0                     112.0     1254.0
# 12631                      80.0                     113.0     1363.5
#
#        MassAirFlow  IntakeAirTemperature  FuelConsumptionAverage  traffic
# 0         6.220000                  15.0               27.919697        1
# 1         6.270000                  15.0               26.458355        1
# 2         6.270000                  15.0               26.458355        1
# 4         8.880000                  15.0               25.295498        1
# 5         8.880000                  15.0               25.295498        1
# ...            ...                   ...                     ...      ...
# 12626    17.910000                  23.0               14.561829        1
# 12627    20.469999                  25.0               14.578003        1
# 12629     9.520000                  24.0               14.547294        1
# 12630    14.910000                  23.0               14.546828        1
# 12631    15.330000                  23.0               14.554068        1
#
# [12471 rows x 10 columns]

# %% [markdown]
# # Declaring the features and the target

# %%
# putting feature variables in X
X = df.drop('traffic',axis=1)
#putting target variable in Y
Y = df['traffic']

# %% [markdown]
# ### up-sampling the traffic dataset

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=42)

# %%
X_smote, Y_smote = smote.fit_resample(X, Y)

# %% [markdown]
# ### Splitting the data into training and testing

# %%
# splitting data into train and test
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X_smote,Y_smote, train_size = 0.65,random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((14860, 9), (8003, 9))

# %% [markdown]
# # Model 1: Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rf = RandomForestClassifier(random_state = 42, n_jobs = 1, max_depth = 5,
                                       n_estimators=100,oob_score=True,max_features=3)

# %%
# %%time
classifier_rf.fit(X_train.values,Y_train.values)
# Out:
# CPU times: total: 844 ms
# Wall time: 1.72 s
# RandomForestClassifier(max_depth=5, max_features=3, n_jobs=1, oob_score=True,
#                        random_state=42)

# %%
classifier_rf.oob_score_
# Out:
# 0.8467025572005383

# %% [markdown]
# ## Introducing grid-search

# %%
# hyper parameter tuning using grid search

rf = RandomForestClassifier(random_state=42,n_jobs=1)

params = {
    'max_depth' : [2,3,5,10,20],
    'min_samples_leaf' : [5,10,20,50,100,200],
    'n_estimators' : [10,25,30,50,100,200]
}

from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(estimator=rf,
                           param_grid=params,
                           cv = 4,
                           n_jobs=1, verbose=1, scoring = "accuracy")

# %%
# %%time
grid_search.fit(X_train.values,Y_train.values)
# Out:
# Fitting 4 folds for each of 180 candidates, totalling 720 fits
# CPU times: total: 4min 43s
# Wall time: 12min 34s
# GridSearchCV(cv=4, estimator=RandomForestClassifier(n_jobs=1, random_state=42),
#              n_jobs=1,
#              param_grid={'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100, 200],
#                          'n_estimators': [10, 25, 30, 50, 100, 200]},
#              scoring='accuracy', verbose=1)

# %%
grid_search.best_score_
# Out:
# 0.9735531628532974

# %%
results_rf = pd.DataFrame(grid_search.cv_results_)
scores_rf = results_rf[['mean_test_score', 'param_n_estimators',  'param_min_samples_leaf']]
scores_rf = scores_rf.sort_values(by = 'mean_test_score',ascending = False)

# %%
scores_rf = scores_rf.nlargest(30,'mean_test_score')

plt.figure(figsize = (15,8))
plt.bar(range(len(scores_rf)),scores_rf['mean_test_score'],align='center')

for i, score in enumerate(scores_rf['mean_test_score']):
    plt.text(i,score,f'{score:.3f}', ha='center', va='bottom')


plt.title('Grid Search Scores')
plt.xlabel('Hyperparameter Combination Index')
plt.ylabel('Mean Test Score')
plt.xticks(range(len(scores_rf)), [f"{row.param_n_estimators}, {row.param_min_samples_leaf}"
                                 for idx, row in scores_rf.iterrows()], rotation=90)

# Adjust layout to fit labels
plt.tight_layout()

# Show the plot
plt.show()

# %%
best_hyperparams = grid_search.best_params_
print("Best Hyperparameters:", best_hyperparams)
# Out:
# Best Hyperparameters: {'max_depth': 20, 'min_samples_leaf': 5, 'n_estimators': 50}

# %%
from sklearn import metrics

# %%
rf_best = grid_search.best_estimator_
rf_best
# Out:
# RandomForestClassifier(max_depth=20, min_samples_leaf=5, n_estimators=50,
#                        n_jobs=1, random_state=42)

# %%
Y_pred = rf_best.predict(X_test)
# Out:
# C:\Users\satvi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(

# %%
print("ACCURACY OF THE MODEL:", metrics.accuracy_score(Y_test, Y_pred))
# Out:
# ACCURACY OF THE MODEL: 0.9813819817568412

# %% [markdown]
# ## Random Forest: 0.9813819817568412

# %% [markdown]
# # Model 2: xg Boost

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score

# Create regression matrices
dtrain_reg = xgb.DMatrix(X_train, Y_train, enable_categorical=True)
dtest_reg = xgb.DMatrix(X_test, Y_test, enable_categorical=True)

# %%
dtrain = xgb.DMatrix(X_train, label=Y_train)
dtest = xgb.DMatrix(X_test, label=Y_test)

# %%
params = {
    'max_depth': 3,  # the maximum depth of each tree
    'eta': 0.1,      # the training step for each iteration
    'objective': 'multi:softprob',  # change this to multi:softprob for probability outputs
    'num_class': 9   # set to the number of classes in the dataset
}
num_rounds = 100  # number of rounds of training

# %%
bst = xgb.train(params, dtrain, num_rounds)

# %%
# Make predictions
preds_prob = bst.predict(dtest)
preds = np.asarray([np.argmax(line) for line in preds_prob])

# Evaluate the predictions
accuracy = accuracy_score(Y_test, preds)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 92.52%

# %% [markdown]
# Initial accuracy: 92.52%

# %% [markdown]
# ## Analysing and improving the accuracy

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate confusion matrix
conf_matrix = confusion_matrix(Y_test, preds)

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.91      0.92      0.92      2634
#            2       0.92      0.89      0.90      2685
#            3       0.95      0.96      0.95      2684
#
#     accuracy                           0.93      8003
#    macro avg       0.92      0.93      0.92      8003
# weighted avg       0.93      0.93      0.93      8003

# %%
xgb.plot_importance(bst)
plt.title("Feature Importance")
plt.show()

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV

param_test = {
    'max_depth': range(3, 10, 2),
    'min_child_weight': range(1, 6, 2)
}



# Adjust labels to start from 0 if they originally start from 1
Y_train_adjusted = Y_train - 1
Y_test_adjusted = Y_test - 1

# Now proceed with GridSearchCV
gsearch = GridSearchCV(
    estimator=xgb.XGBClassifier(learning_rate=0.1, num_class=3, objective='multi:softmax'),  # Ensure num_class and objective are correctly set
    param_grid=param_test,
    scoring='accuracy',
    n_jobs=-1,
    cv=5
)
gsearch.fit(X_train, Y_train_adjusted)
print(gsearch.best_params_, gsearch.best_score_)
# Out:
# {'max_depth': 9, 'min_child_weight': 5} 0.9836473755047106

# %% [markdown]
# ### xgboost accuracy: 0.9836473755047106

# %% [markdown]
# # Model 3: Ada boost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
# Initialize the base estimator
base_estimator = DecisionTreeClassifier(max_depth=1)

# Initialize the AdaBoost classifier with the correct parameter name
ada = AdaBoostClassifier(estimator=base_estimator, n_estimators=50, learning_rate=1.0)

# Train the AdaBoost model
ada.fit(X_train, Y_train)
# Out:
# C:\Users\satvi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1))

# %%
# Train the AdaBoost model
ada.fit(X_train, Y_train)
# Out:
# C:\Users\satvi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1))

# %%
# Make predictions on the test set
y_pred = ada.predict(X_test)

# %%
# Calculate and print the accuracy
accuracy = accuracy_score(Y_test, y_pred)
print(f'AdaBoost Accuracy: {accuracy}')
# Out:
# AdaBoost Accuracy: 0.7512182931400725

# %% [markdown]
# # AdaBoost needs to be improved

# %% [markdown]
# ## Saving the models

# %%
import pickle

# %%
with open('random_forest.pkl', 'wb') as file:
    pickle.dump(rf_best, file)

# %%
with open('xgBoost.pkl', 'wb') as file:
    pickle.dump(gsearch, file)
